# %% [markdown]
# ### Import necessary Library

# %%
import argparse
import getpass
import imaplib
import poplib
import smtplib

# %% [markdown]
# ### Popular Email Server
#
# Here are the list of several popular email servers:
#
# ![img_1](img/img_1.jpg)
# ![img_2](img/img_2.jpg)
# ![img_3](img/img_3.jpg)

# %%
IMAP_SERVER = 'outlook.office365.com'
IMAP_PORT = 993

POP_SERVER = 'outlook.office365.com'
POP_PORT = 995

# %%
def imap_mail(username): 
    mailbox = imaplib.IMAP4_SSL(IMAP_SERVER, IMAP_PORT) 
    password = getpass.getpass(prompt='Enter your email password: ') 
    mailbox.login(username, password)
    mailbox.select('Inbox')
    typ, data = mailbox.search(None, 'ALL')
    for num in data[0].split():
        typ, data = mailbox.fetch(num, '(RFC822)')
        print ('Message %s\n%s\n' % (num, data[0][1]))
        break
    mailbox.close()
    mailbox.logout()
    
def pop_mail(username): 
    mailbox = poplib.POP3_SSL(POP_SERVER, POP_PORT) 
    mailbox.user(username)
    password = getpass.getpass(prompt='Enter your email password: ') 
    mailbox.pass_(password) 
    num_messages = len(mailbox.list()[1])
    print ('Total emails: {}'.format(num_messages))
    mailbox.quit()

# %%
imap_mail('170010033@stikom-bali.ac.id')
# Out:
# Enter your email password: ········
# Message b'1'
# b'Received: from SG2PR06MB3110.apcprd06.prod.outlook.com (2603:1096:404:15::36)\r\n by TYAPR06MB2125.apcprd06.prod.outlook.com with HTTPS via\r\n TYAPR04CA0024.APCPRD04.PROD.OUTLOOK.COM; Wed, 18 Mar 2020 14:10:40 +0000\r\nARC-Seal: i=2; a=rsa-sha256; s=arcselector9901; d=microsoft.com; cv=pass;\r\n b=\r\nARC-Message-Signature: i=2; a=rsa-sha256; c=relaxed/relaxed; d=microsoft.com;\r\n s=arcselector9901;\r\n h=From:Date:Subject:Message-ID:Content-Type:MIME-Version:X-MS-Exchange-SenderADCheck;\r\n bh=q2IKQNj5K/ghnoXGuJ28k6TriZ/+e5Ri4rBstYcPI/E=;\r\n b=\r\nARC-Authentication-Results: i=2; mx.microsoft.com 1; spf=pass (sender ip is\r\n 40.107.243.66) smtp.rcpttodomain=stikom-bali.ac.id\r\n smtp.mailfrom=email.teams.microsoft.com; dmarc=pass (p=reject sp=reject\r\n pct=100) action=none header.from=email.teams.microsoft.com; dkim=pass\r\n (signature was verified) header.d=email.teams.microsoft.com; arc=pass (0\r\n oda=1 ltdi=1 spf=[1,1,smtp.mailfrom=email.teams.microsoft.com]\r\n dmarc=[1,1,header.from=email.teams.microsoft.com])\r\nReceived: from HK2PR04CA0044.apcprd04.prod.outlook.com (2603:1096:202:14::12)\r\n by SG2PR06MB3110.apcprd06.prod.outlook.com (2603:1096:4:6c::22) with\r\n Microsoft SMTP Server (version=TLS1_2,\r\n cipher=TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384) id 15.20.2814.22; Wed, 18 Mar\r\n 2020 14:10:39 +0000\r\nReceived: from HK2APC01FT042.eop-APC01.prod.protection.outlook.com\r\n (2603:1096:202:14:cafe::1f) by HK2PR04CA0044.outlook.office365.com\r\n (2603:1096:202:14::12) with Microsoft SMTP Server (version=TLS1_2,\r\n cipher=TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384) id 15.20.2814.18 via Frontend\r\n Transport; Wed, 18 Mar 2020 14:10:38 +0000\r\nAuthentication-Results: spf=pass (sender IP is 40.107.243.66)\r\n smtp.mailfrom=email.teams.microsoft.com; stikom-bali.ac.id; dkim=pass\r\n (signature was verified)\r\n header.d=email.teams.microsoft.com;stikom-bali.ac.id; dmarc=pass action=none\r\n header.from=email.teams.microsoft.com;compauth=pass reason=100\r\nReceived-SPF: Pass (protection.outlook.com: domain of\r\n email.teams.microsoft.com designates 40.107.243.66 as permitted sender)\r\n receiver=protection.outlook.com; client-ip=40.107.243.66;\r\n helo=NAM12-DM6-obe.outbound.protection.outlook.com;\r\nReceived: from NAM12-DM6-obe.outbound.protection.outlook.com (40.107.243.66)\r\n by HK2APC01FT042.mail.protection.outlook.com (10.152.249.66) with Microsoft\r\n SMTP Server (version=TLS1_2, cipher=TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384) id\r\n 15.20.2814.13 via Frontend Transport; Wed, 18 Mar 2020 14:10:37 +0000\r\nARC-Seal: i=1; a=rsa-sha256; s=arcselector9901; d=microsoft.com; cv=none;\r\n b=\r\nARC-Message-Signature: i=1; a=rsa-sha256; c=relaxed/relaxed; d=microsoft.com;\r\n s=arcselector9901;\r\n h=From:Date:Subject:Message-ID:Content-Type:MIME-Version:X-MS-Exchange-SenderADCheck;\r\n bh=q2IKQNj5K/ghnoXGuJ28k6TriZ/+e5Ri4rBstYcPI/E=;\r\n b=lzZuXlAZWKXokXbzwRBWnxp+6shJj0WBLyAtLmxZxrFeF5GAp/hO149j0KdvDMH8bcbr ...

# %%
pop_mail('170010033@stikom-bali.ac.id')
# Out:
# Enter your email password: ········
# Total emails: 12
